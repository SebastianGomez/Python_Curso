# %%
import csv

# %%
with open("ejemploCSV.csv") as archivo:
    leer = csv.reader(archivo)
    print(leer)
#devuelve un objeto csv, que es un iterable

# %%
# leer un objeto csv

with open("ejemploCSV.csv") as archivo:
    leer = csv.reader(archivo)
    for row in leer:
        print(row)
# Out:
# ['nombre', 'apellido', 'edad']
# ['Pedro', ' Lopez', ' 40']
# ['Jose', ' Ortiz', ' 20']
# ['Laura', ' Farias', ' 30']
# ['Andrea', ' Rincon', ' 55']
