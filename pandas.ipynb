# %%
import pandas as pd

# %%
#Leer un archivo csv
df = pd.read_csv("ejemploCSV.csv")
print(df)
# Out:
#    nombre apellido  edad
# 0   Pedro    Lopez    40
# 1    Jose    Ortiz    20
# 2   Laura   Farias    30
# 3  Andrea   Rincon    55

# %%
#Leer datos de una sola columna
print(df["nombre"])
# Out:
# 0     Pedro
# 1      Jose
# 2     Laura
# 3    Andrea
# Name: nombre, dtype: object

# %%
#agregar columnas de datos
df = pd.read_csv("ejemploCSV.csv",names=["name","lastname","age"])
print(df)
# Out:
#      name  lastname   age
# 0  nombre  apellido  edad
# 1   Pedro     Lopez    40
# 2    Jose     Ortiz    20
# 3   Laura    Farias    30
# 4  Andrea    Rincon    55
